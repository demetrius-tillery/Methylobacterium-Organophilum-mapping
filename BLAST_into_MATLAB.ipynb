# %%
import pandas as pd
import re
from Bio.Blast import NCBIWWW, NCBIXML
from Bio.Blast.Applications import NcbiblastpCommandline
import os
# Out:
# /home/skylite/anaconda3/lib/python3.13/site-packages/Bio/Application/__init__.py:39: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
###This script requires the AA sequences of desired bacteria. Use my "KEGG_ID_to_AA_seq" code for guidance to proceed.
###This script also requires a local BLAST database to be installed, this is due to NCBI Blast having a request limit from one IP.
###I recommend swissprot, at least to start out with. If you have any questions or issues email me at dtillery@sdsu.edu.

#Loads CSV. Replace the file name in quotations, make sure the script and the file are in the same folder.
df = pd.read_csv("AA_MethyOrg_Results.csv") ##Put your file name in, it has to be in .csv format.
db = "/home/skylite/blastdb/swissprot" ##this calls to where I have swissprot saved at. It will be a different directory for you wherever you install yours. Change this as well.

# %%
##THis puts our FASTA and BLAST requests files somewhere because there will most likely be a lot generated. Change folder names as you see fit.
fasta_folder = "fasta_queries"
os.makedirs(fasta_folder, exist_ok=True)
blast_folder = "blast_results"
os.makedirs(blast_folder, exist_ok=True)

# %%
#This function will run BLAST locally through SwissProt and parse top hits, this will also save any FASTA matching files to a new folder as well as BLAST logs.
#I would recommend keeping the BLAST logs, at least temporarily, in case you need to manually look through them and see if you want to refine your search"
def run_local_blast(sequence, idx):
    #Save FASTA to fasta_folder
    fasta_path = os.path.join(fasta_folder, f"query_{idx}.fasta")
    with open(fasta_path, "w") as f:
        f.write(f">query_{idx}\n{sequence}\n")

    #Save BLAST result to blast_folder
    output_path = os.path.join(blast_folder, f"blast_result_{idx}.xml")
    blast_cline = NcbiblastpCommandline(
        query=fasta_path,
        db=db,
        evalue=0.001,
        outfmt=5,
        out=output_path
    )
    blast_cline()

    with open(output_path) as result_handle:
        blast_record = NCBIXML.read(result_handle)

    return parse_blast_hits(blast_record)

# %%
#This function searches for our organism. It isn't case sensitive and I have it searching for methylobacterium. Replace the name to whatever you want.
#I recommend changing anything that says methylobacterium to how you see fit to avoid confusion.
def parse_blast_hits(blast_record):
    methylobacterium_hits = []

    for alignment in blast_record.alignments:
        hit_def = alignment.hit_def #hit_def is what it's called in BLAST. This is the gene name it'll look something like this: MMB17_RS12660 adenosylhomocysteinase [Methylobacterium extorquens]
        acc = alignment.hit_id #hit_id is an accension id, this is a unique code to the BLAST run that makes it easier to search up. You don't need to keep this.

        # Check if 'Methylobacterium' appears (case-insensitive)
        if re.search(r'methylobacterium', hit_def, re.IGNORECASE):
            #Extract organism name from brackets, if you look in the BLAST logs, you'll see it puts organism names in brackets.
            match = re.search(r'\[(.*?)\]$', hit_def)
            organism = match.group(1) if match else "Unknown_Organism"

            methylobacterium_hits.append(f"{acc} [{organism}]")

    return methylobacterium_hits if methylobacterium_hits else ["No Methylobacterium match"]

# %%
##Process all AA sequences, this portions ties in everything and performs BLAST on every AA sequence we found using swissprot local database##
gpr_list = []

for idx, sequence in enumerate(df['UniProt_AA_Sequences']):
    print(f"🔍 BLASTing row {idx}...")

    if pd.isna(sequence) or "No sequence" in str(sequence):
        print(f"⚠️ Skipping row {idx} — no sequence available.")
        gpr_list.append("No sequence")
        continue

    try:
        matches = run_local_blast(str(sequence), idx)

        if matches == ["No Methylobacterium match"]:
            print(f"❌ No Methylobacterium match found in row {idx}.")
            gpr_list.append("No valid GPR")
        else:
            result_str = " & ".join(matches)
            print(f"✅ Match(es) found: {result_str}")
            gpr_list.append(result_str)

    except Exception as e:
        print(f"🚨 Error in row {idx}: {e}")
        gpr_list.append("Error")
# Out:
# 🔍 BLASTing row 0...
# ❌ No Methylobacterium match found in row 0.
# 🔍 BLASTing row 1...
# ❌ No Methylobacterium match found in row 1.
# 🔍 BLASTing row 2...
# ❌ No Methylobacterium match found in row 2.
# 🔍 BLASTing row 3...
# ❌ No Methylobacterium match found in row 3.
# 🔍 BLASTing row 4...
# ❌ No Methylobacterium match found in row 4.
# 🔍 BLASTing row 5...
# ✅ Match(es) found: sp|B0UI66.1| [Methylobacterium sp. 4-46] & sp|B8IUT2.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 6...
# ⚠️ Skipping row 6 — no sequence available.
# 🔍 BLASTing row 7...
# ❌ No Methylobacterium match found in row 7.
# 🔍 BLASTing row 8...
# ❌ No Methylobacterium match found in row 8.
# 🔍 BLASTing row 9...
# ❌ No Methylobacterium match found in row 9.
# 🔍 BLASTing row 10...
# ❌ No Methylobacterium match found in row 10.
# 🔍 BLASTing row 11...
# ❌ No Methylobacterium match found in row 11.
# 🔍 BLASTing row 12...
# ❌ No Methylobacterium match found in row 12.
# 🔍 BLASTing row 13...
# ❌ No Methylobacterium match found in row 13.
# 🔍 BLASTing row 14...
# ❌ No Methylobacterium match found in row 14.
# 🔍 BLASTing row 15...
# ❌ No Methylobacterium match found in row 15.
# 🔍 BLASTing row 16...
# ❌ No Methylobacterium match found in row 16.
# 🔍 BLASTing row 17...
# ❌ No Methylobacterium match found in row 17.
# 🔍 BLASTing row 18...
# ❌ No Methylobacterium match found in row 18.
# 🔍 BLASTing row 19...
# ✅ Match(es) found: sp|B8IPH4.1| [(5-phosphoribosylamino)methylideneamino] imidazole-4-carboxamide isomerase; AltName: Full=Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [Methylobacterium nodulans ORS 2060] & sp|B0UHR6.1| [(5-phosphoribosylamino)methylideneamino] imidazole-4-carboxamide isomerase; AltName: Full=Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 20...
# ❌ No Methylobacterium match found in row 20.
# 🔍 BLASTing row 21...
# ❌ No Methylobacterium match found in row 21.
# 🔍 BLASTing row 22...
# ❌ No Methylobacterium match found in row 22.
# 🔍 BLASTing row 23...
# ❌ No Methylobacterium match found in row 23.
# 🔍 BLASTing row 24...
# ✅ Match(es) found: sp|B1LTP4.1| [acyl-carrier-protein]--UDP-N-acetylglucosamine O-acyltransferase; Short=UDP-N-acetylglucosamine acyltransferase [Methylobacterium radiotolerans JCM 2831] & sp|B1LTP6.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8INJ6.1| [Methylobacterium nodulans ORS 2060] & sp|B0UQ03.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 25...
# ❌ No Methylobacterium match found in row 25.
# 🔍 BLASTing row 26...
# ❌ No Methylobacterium match found in row 26.
# 🔍 BLASTing row 27...
# ❌ No Methylobacterium match found in row 27.
# 🔍 BLASTing row 28...
# ❌ No Methylobacterium match found in row 28.
# 🔍 BLASTing row 29...
# ❌ No Methylobacterium match found in row 29.
# 🔍 BLASTing row 30...
# ❌ No Methylobacterium match found in row 30.
# 🔍 BLASTing row 31...
# ❌ No Methylobacterium match found in row 31.
# 🔍 BLASTing row 32...
# ❌ No Methylobacterium match found in row 32.
# 🔍 BLASTing row 33...
# ❌ No Methylobacterium match found in row 33.
# 🔍 BLASTing row 34...
# ❌ No Methylobacterium match found in row 34.
# 🔍 BLASTing row 35...
# ❌ No Methylobacterium match found in row 35.
# 🔍 BLASTing row 36...
# ✅ Match(es) found: sp|B0UAK2.1| [Methylobacterium sp. 4-46] & sp|B8ITG7.1| [Methylobacterium nodulans ORS 2060] & sp|B1LSF9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UDK8.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 37...
# ❌ No Methylobacterium match found in row 37.
# 🔍 BLASTing row 38...
# ❌ No Methylobacterium match found in row 38.
# 🔍 BLASTing row 39...
# ❌ No Methylobacterium match found in row 39.
# 🔍 BLASTing row 40...
# ❌ No Methylobacterium match found in row 40.
# 🔍 BLASTing row 41...
# ❌ No Methylobacterium match found in row 41.
# 🔍 BLASTing row 42...
# ❌ No Methylobacterium match found in row 42.
# 🔍 BLASTing row 43...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWQ5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 44...
# ❌ No Methylobacterium match found in row 44.
# 🔍 BLASTing row 45...
# ✅ Match(es) found: sp|B8ITV7.1| [Methylobacterium nodulans ORS 2060] & sp|B1LUE7.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UE13.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 46...
# ❌ No Methylobacterium match found in row 46.
# 🔍 BLASTing row 47...
# ❌ No Methylobacterium match found in row 47.
# 🔍 BLASTing row 48...
# ✅ Match(es) found: sp|B1M3B2.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 49...
# ❌ No Methylobacterium match found in row 49.
# 🔍 BLASTing row 50...
# ❌ No Methylobacterium match found in row 50.
# 🔍 BLASTing row 51...
# ❌ No Methylobacterium match found in row 51.
# 🔍 BLASTing row 52...
# ❌ No Methylobacterium match found in row 52.
# 🔍 BLASTing row 53...
# ❌ No Methylobacterium match found in row 53.
# 🔍 BLASTing row 54...
# ❌ No Methylobacterium match found in row 54.
# 🔍 BLASTing row 55...
# ❌ No Methylobacterium match found in row 55.
# 🔍 BLASTing row 56...
# ❌ No Methylobacterium match found in row 56.
# 🔍 BLASTing row 57...
# ❌ No Methylobacterium match found in row 57.
# 🔍 BLASTing row 58...
# ❌ No Methylobacterium match found in row 58.
# 🔍 BLASTing row 59...
# ❌ No Methylobacterium match found in row 59.
# 🔍 BLASTing row 60...
# ✅ Match(es) found: sp|B0UBD4.1| [Methylobacterium sp. 4-46] & sp|B1M6A7.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 61...
# ❌ No Methylobacterium match found in row 61.
# 🔍 BLASTing row 62...
# ❌ No Methylobacterium match found in row 62.
# 🔍 BLASTing row 63...
# ❌ No Methylobacterium match found in row 63.
# 🔍 BLASTing row 64...
# ❌ No Methylobacterium match found in row 64.
# 🔍 BLASTing row 65...
# ❌ No Methylobacterium match found in row 65.
# 🔍 BLASTing row 66...
# ✅ Match(es) found: sp|B0UCF0.1| [Methylobacterium sp. 4-46] & sp|B8IJB4.1| [Methylobacterium nodulans ORS 2060] & sp|B1LZN1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 67...
# ❌ No Methylobacterium match found in row 67.
# 🔍 BLASTing row 68...
# ❌ No Methylobacterium match found in row 68.
# 🔍 BLASTing row 69...
# ❌ No Methylobacterium match found in row 69.
# 🔍 BLASTing row 70...
# ❌ No Methylobacterium match found in row 70.
# 🔍 BLASTing row 71...
# ✅ Match(es) found: sp|B1M0M1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 72...
# ❌ No Methylobacterium match found in row 72.
# 🔍 BLASTing row 73...
# ❌ No Methylobacterium match found in row 73.
# 🔍 BLASTing row 74...
# ✅ Match(es) found: sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 75...
# ✅ Match(es) found: sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 76...
# ❌ No Methylobacterium match found in row 76.
# 🔍 BLASTing row 77...
# ❌ No Methylobacterium match found in row 77.
# 🔍 BLASTing row 78...
# ❌ No Methylobacterium match found in row 78.
# 🔍 BLASTing row 79...
# ❌ No Methylobacterium match found in row 79.
# 🔍 BLASTing row 80...
# ❌ No Methylobacterium match found in row 80.
# 🔍 BLASTing row 81...
# ✅ Match(es) found: sp|B0UKF2.1| [Methylobacterium sp. 4-46] & sp|B8ILP3.1| [Methylobacterium nodulans ORS 2060] & sp|B1LUP7.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 82...
# ❌ No Methylobacterium match found in row 82.
# 🔍 BLASTing row 83...
# ❌ No Methylobacterium match found in row 83.
# 🔍 BLASTing row 84...
# ❌ No Methylobacterium match found in row 84.
# 🔍 BLASTing row 85...
# ❌ No Methylobacterium match found in row 85.
# 🔍 BLASTing row 86...
# ❌ No Methylobacterium match found in row 86.
# 🔍 BLASTing row 87...
# ❌ No Methylobacterium match found in row 87.
# 🔍 BLASTing row 88...
# ❌ No Methylobacterium match found in row 88.
# 🔍 BLASTing row 89...
# ❌ No Methylobacterium match found in row 89.
# 🔍 BLASTing row 90...
# ❌ No Methylobacterium match found in row 90.
# 🔍 BLASTing row 91...
# ✅ Match(es) found: sp|B1LYB4.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 92...
# ❌ No Methylobacterium match found in row 92.
# 🔍 BLASTing row 93...
# ❌ No Methylobacterium match found in row 93.
# 🔍 BLASTing row 94...
# ❌ No Methylobacterium match found in row 94.
# 🔍 BLASTing row 95...
# ❌ No Methylobacterium match found in row 95.
# 🔍 BLASTing row 96...
# ❌ No Methylobacterium match found in row 96.
# 🔍 BLASTing row 97...
# ❌ No Methylobacterium match found in row 97.
# 🔍 BLASTing row 98...
# ❌ No Methylobacterium match found in row 98.
# 🔍 BLASTing row 99...
# ❌ No Methylobacterium match found in row 99.
# 🔍 BLASTing row 100...
# ❌ No Methylobacterium match found in row 100.
# 🔍 BLASTing row 101...
# ❌ No Methylobacterium match found in row 101.
# 🔍 BLASTing row 102...
# ❌ No Methylobacterium match found in row 102.
# 🔍 BLASTing row 103...
# ❌ No Methylobacterium match found in row 103.
# 🔍 BLASTing row 104...
# ❌ No Methylobacterium match found in row 104.
# 🔍 BLASTing row 105...
# ❌ No Methylobacterium match found in row 105.
# 🔍 BLASTing row 106...
# ❌ No Methylobacterium match found in row 106.
# 🔍 BLASTing row 107...
# ❌ No Methylobacterium match found in row 107.
# 🔍 BLASTing row 108...
# ❌ No Methylobacterium match found in row 108.
# 🔍 BLASTing row 109...
# ❌ No Methylobacterium match found in row 109.
# 🔍 BLASTing row 110...
# ❌ No Methylobacterium match found in row 110.
# 🔍 BLASTing row 111...
# ❌ No Methylobacterium match found in row 111.
# 🔍 BLASTing row 112...
# ❌ No Methylobacterium match found in row 112.
# 🔍 BLASTing row 113...
# ❌ No Methylobacterium match found in row 113.
# 🔍 BLASTing row 114...
# ❌ No Methylobacterium match found in row 114.
# 🔍 BLASTing row 115...
# ❌ No Methylobacterium match found in row 115.
# 🔍 BLASTing row 116...
# ❌ No Methylobacterium match found in row 116.
# 🔍 BLASTing row 117...
# ❌ No Methylobacterium match found in row 117.
# 🔍 BLASTing row 118...
# ❌ No Methylobacterium match found in row 118.
# 🔍 BLASTing row 119...
# ❌ No Methylobacterium match found in row 119.
# 🔍 BLASTing row 120...
# ❌ No Methylobacterium match found in row 120.
# 🔍 BLASTing row 121...
# ❌ No Methylobacterium match found in row 121.
# 🔍 BLASTing row 122...
# ✅ Match(es) found: sp|B1LZB2.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IPI3.1| [Methylobacterium nodulans ORS 2060] & sp|B0UHS5.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 123...
# ✅ Match(es) found: sp|B8IM39.1| [Methylobacterium nodulans ORS 2060] & sp|B0UA74.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 124...
# ✅ Match(es) found: sp|B8ID24.1| [Methylobacterium nodulans ORS 2060] & sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 125...
# ❌ No Methylobacterium match found in row 125.
# 🔍 BLASTing row 126...
# ❌ No Methylobacterium match found in row 126.
# 🔍 BLASTing row 127...
# ❌ No Methylobacterium match found in row 127.
# 🔍 BLASTing row 128...
# ❌ No Methylobacterium match found in row 128.
# 🔍 BLASTing row 129...
# ❌ No Methylobacterium match found in row 129.
# 🔍 BLASTing row 130...
# ❌ No Methylobacterium match found in row 130.
# 🔍 BLASTing row 131...
# ❌ No Methylobacterium match found in row 131.
# 🔍 BLASTing row 132...
# ❌ No Methylobacterium match found in row 132.
# 🔍 BLASTing row 133...
# ❌ No Methylobacterium match found in row 133.
# 🔍 BLASTing row 134...
# ❌ No Methylobacterium match found in row 134.
# 🔍 BLASTing row 135...
# ❌ No Methylobacterium match found in row 135.
# 🔍 BLASTing row 136...
# ❌ No Methylobacterium match found in row 136.
# 🔍 BLASTing row 137...
# ❌ No Methylobacterium match found in row 137.
# 🔍 BLASTing row 138...
# ❌ No Methylobacterium match found in row 138.
# 🔍 BLASTing row 139...
# ❌ No Methylobacterium match found in row 139.
# 🔍 BLASTing row 140...
# ❌ No Methylobacterium match found in row 140.
# 🔍 BLASTing row 141...
# ❌ No Methylobacterium match found in row 141.
# 🔍 BLASTing row 142...
# ❌ No Methylobacterium match found in row 142.
# 🔍 BLASTing row 143...
# ❌ No Methylobacterium match found in row 143.
# 🔍 BLASTing row 144...
# ❌ No Methylobacterium match found in row 144.
# 🔍 BLASTing row 145...
# ✅ Match(es) found: sp|B0UKC4.1| [Methylobacterium sp. 4-46] & sp|B8IP71.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 146...
# ❌ No Methylobacterium match found in row 146.
# 🔍 BLASTing row 147...
# ❌ No Methylobacterium match found in row 147.
# 🔍 BLASTing row 148...
# ✅ Match(es) found: sp|B8IIZ9.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWY6.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UR68.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 149...
# ❌ No Methylobacterium match found in row 149.
# 🔍 BLASTing row 150...
# ❌ No Methylobacterium match found in row 150.
# 🔍 BLASTing row 151...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 152...
# ❌ No Methylobacterium match found in row 152.
# 🔍 BLASTing row 153...
# ❌ No Methylobacterium match found in row 153.
# 🔍 BLASTing row 154...
# ❌ No Methylobacterium match found in row 154.
# 🔍 BLASTing row 155...
# ❌ No Methylobacterium match found in row 155.
# 🔍 BLASTing row 156...
# ❌ No Methylobacterium match found in row 156.
# 🔍 BLASTing row 157...
# ❌ No Methylobacterium match found in row 157.
# 🔍 BLASTing row 158...
# ❌ No Methylobacterium match found in row 158.
# 🔍 BLASTing row 159...
# ❌ No Methylobacterium match found in row 159.
# 🔍 BLASTing row 160...
# ❌ No Methylobacterium match found in row 160.
# 🔍 BLASTing row 161...
# ❌ No Methylobacterium match found in row 161.
# 🔍 BLASTing row 162...
# ❌ No Methylobacterium match found in row 162.
# 🔍 BLASTing row 163...
# ❌ No Methylobacterium match found in row 163.
# 🔍 BLASTing row 164...
# ❌ No Methylobacterium match found in row 164.
# 🔍 BLASTing row 165...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 166...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 167...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 168...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 169...
# ❌ No Methylobacterium match found in row 169.
# 🔍 BLASTing row 170...
# ❌ No Methylobacterium match found in row 170.
# 🔍 BLASTing row 171...
# ❌ No Methylobacterium match found in row 171.
# 🔍 BLASTing row 172...
# ❌ No Methylobacterium match found in row 172.
# 🔍 BLASTing row 173...
# ❌ No Methylobacterium match found in row 173.
# 🔍 BLASTing row 174...
# ❌ No Methylobacterium match found in row 174.
# 🔍 BLASTing row 175...
# ❌ No Methylobacterium match found in row 175.
# 🔍 BLASTing row 176...
# ❌ No Methylobacterium match found in row 176.
# 🔍 BLASTing row 177...
# ❌ No Methylobacterium match found in row 177.
# 🔍 BLASTing row 178...
# ❌ No Methylobacterium match found in row 178.
# 🔍 BLASTing row 179...
# ❌ No Methylobacterium match found in row 179.
# 🔍 BLASTing row 180...
# ❌ No Methylobacterium match found in row 180.
# 🔍 BLASTing row 181...
# ❌ No Methylobacterium match found in row 181.
# 🔍 BLASTing row 182...
# ❌ No Methylobacterium match found in row 182.
# 🔍 BLASTing row 183...
# ❌ No Methylobacterium match found in row 183.
# 🔍 BLASTing row 184...
# ❌ No Methylobacterium match found in row 184.
# 🔍 BLASTing row 185...
# ❌ No Methylobacterium match found in row 185.
# 🔍 BLASTing row 186...
# ✅ Match(es) found: sp|B1LUA2.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IPH3.1| [Methylobacterium nodulans ORS 2060] & sp|B0UHR5.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 187...
# ❌ No Methylobacterium match found in row 187.
# 🔍 BLASTing row 188...
# ❌ No Methylobacterium match found in row 188.
# 🔍 BLASTing row 189...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 190...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 191...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 192...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 193...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 194...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 195...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 196...
# ❌ No Methylobacterium match found in row 196.
# 🔍 BLASTing row 197...
# ❌ No Methylobacterium match found in row 197.
# 🔍 BLASTing row 198...
# ❌ No Methylobacterium match found in row 198.
# 🔍 BLASTing row 199...
# ❌ No Methylobacterium match found in row 199.
# 🔍 BLASTing row 200...
# ❌ No Methylobacterium match found in row 200.
# 🔍 BLASTing row 201...
# ❌ No Methylobacterium match found in row 201.
# 🔍 BLASTing row 202...
# ❌ No Methylobacterium match found in row 202.
# 🔍 BLASTing row 203...
# ❌ No Methylobacterium match found in row 203.
# 🔍 BLASTing row 204...
# ❌ No Methylobacterium match found in row 204.
# 🔍 BLASTing row 205...
# ❌ No Methylobacterium match found in row 205.
# 🔍 BLASTing row 206...
# ❌ No Methylobacterium match found in row 206.
# 🔍 BLASTing row 207...
# ❌ No Methylobacterium match found in row 207.
# 🔍 BLASTing row 208...
# ❌ No Methylobacterium match found in row 208.
# 🔍 BLASTing row 209...
# ❌ No Methylobacterium match found in row 209.
# 🔍 BLASTing row 210...
# ❌ No Methylobacterium match found in row 210.
# 🔍 BLASTing row 211...
# ❌ No Methylobacterium match found in row 211.
# 🔍 BLASTing row 212...
# ✅ Match(es) found: sp|B0U811.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 213...
# ❌ No Methylobacterium match found in row 213.
# 🔍 BLASTing row 214...
# ❌ No Methylobacterium match found in row 214.
# 🔍 BLASTing row 215...
# ❌ No Methylobacterium match found in row 215.
# 🔍 BLASTing row 216...
# ❌ No Methylobacterium match found in row 216.
# 🔍 BLASTing row 217...
# ❌ No Methylobacterium match found in row 217.
# 🔍 BLASTing row 218...
# ❌ No Methylobacterium match found in row 218.
# 🔍 BLASTing row 219...
# ✅ Match(es) found: sp|B0U811.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 220...
# ❌ No Methylobacterium match found in row 220.
# 🔍 BLASTing row 221...
# ❌ No Methylobacterium match found in row 221.
# 🔍 BLASTing row 222...
# ❌ No Methylobacterium match found in row 222.
# 🔍 BLASTing row 223...
# ✅ Match(es) found: sp|B0UMS9.1| [Methylobacterium sp. 4-46] & sp|B8IEM1.1| [Methylobacterium nodulans ORS 2060] & sp|B1M695.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 224...
# ❌ No Methylobacterium match found in row 224.
# 🔍 BLASTing row 225...
# ✅ Match(es) found: sp|B1M0M1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 226...
# ❌ No Methylobacterium match found in row 226.
# 🔍 BLASTing row 227...
# ❌ No Methylobacterium match found in row 227.
# 🔍 BLASTing row 228...
# ✅ Match(es) found: sp|B0UL61.1| [Methylobacterium sp. 4-46] & sp|B1M0I6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 229...
# ❌ No Methylobacterium match found in row 229.
# 🔍 BLASTing row 230...
# ❌ No Methylobacterium match found in row 230.
# 🔍 BLASTing row 231...
# ❌ No Methylobacterium match found in row 231.
# 🔍 BLASTing row 232...
# ❌ No Methylobacterium match found in row 232.
# 🔍 BLASTing row 233...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWQ5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 234...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWQ5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 235...
# ❌ No Methylobacterium match found in row 235.
# 🔍 BLASTing row 236...
# ❌ No Methylobacterium match found in row 236.
# 🔍 BLASTing row 237...
# ❌ No Methylobacterium match found in row 237.
# 🔍 BLASTing row 238...
# ❌ No Methylobacterium match found in row 238.
# 🔍 BLASTing row 239...
# ❌ No Methylobacterium match found in row 239.
# 🔍 BLASTing row 240...
# ❌ No Methylobacterium match found in row 240.
# 🔍 BLASTing row 241...
# ❌ No Methylobacterium match found in row 241.
# 🔍 BLASTing row 242...
# ❌ No Methylobacterium match found in row 242.
# 🔍 BLASTing row 243...
# ❌ No Methylobacterium match found in row 243.
# 🔍 BLASTing row 244...
# ❌ No Methylobacterium match found in row 244.
# 🔍 BLASTing row 245...
# ❌ No Methylobacterium match found in row 245.
# 🔍 BLASTing row 246...
# ❌ No Methylobacterium match found in row 246.
# 🔍 BLASTing row 247...
# ❌ No Methylobacterium match found in row 247.
# 🔍 BLASTing row 248...
# ❌ No Methylobacterium match found in row 248.
# 🔍 BLASTing row 249...
# ❌ No Methylobacterium match found in row 249.
# 🔍 BLASTing row 250...
# ❌ No Methylobacterium match found in row 250.
# 🔍 BLASTing row 251...
# ❌ No Methylobacterium match found in row 251.
# 🔍 BLASTing row 252...
# ❌ No Methylobacterium match found in row 252.
# 🔍 BLASTing row 253...
# ❌ No Methylobacterium match found in row 253.
# 🔍 BLASTing row 254...
# ❌ No Methylobacterium match found in row 254.
# 🔍 BLASTing row 255...
# ❌ No Methylobacterium match found in row 255.
# 🔍 BLASTing row 256...
# ❌ No Methylobacterium match found in row 256.
# 🔍 BLASTing row 257...
# ❌ No Methylobacterium match found in row 257.
# 🔍 BLASTing row 258...
# ❌ No Methylobacterium match found in row 258.
# 🔍 BLASTing row 259...
# ❌ No Methylobacterium match found in row 259.
# 🔍 BLASTing row 260...
# ❌ No Methylobacterium match found in row 260.
# 🔍 BLASTing row 261...
# ❌ No Methylobacterium match found in row 261.
# 🔍 BLASTing row 262...
# ❌ No Methylobacterium match found in row 262.
# 🔍 BLASTing row 263...
# ✅ Match(es) found: sp|B1M7L6.1| [NAD(P)+]; AltName: Full=NAD(P)(+)-dependent glycerol-3-phosphate dehydrogenase; AltName: Full=NAD(P)H-dependent dihydroxyacetone-phosphate reductase [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 264...
# ✅ Match(es) found: sp|B1M7L6.1| [NAD(P)+]; AltName: Full=NAD(P)(+)-dependent glycerol-3-phosphate dehydrogenase; AltName: Full=NAD(P)H-dependent dihydroxyacetone-phosphate reductase [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 265...
# ❌ No Methylobacterium match found in row 265.
# 🔍 BLASTing row 266...
# ✅ Match(es) found: sp|B1M509.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8ILR2.1| [Methylobacterium nodulans ORS 2060] & sp|B0UJ26.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 267...
# ❌ No Methylobacterium match found in row 267.
# 🔍 BLASTing row 268...
# ❌ No Methylobacterium match found in row 268.
# 🔍 BLASTing row 269...
# ❌ No Methylobacterium match found in row 269.
# 🔍 BLASTing row 270...
# ❌ No Methylobacterium match found in row 270.
# 🔍 BLASTing row 271...
# ✅ Match(es) found: sp|B0UKC4.1| [Methylobacterium sp. 4-46] & sp|B8IP71.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 272...
# ❌ No Methylobacterium match found in row 272.
# 🔍 BLASTing row 273...
# ✅ Match(es) found: sp|B1M0M1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 274...
# ❌ No Methylobacterium match found in row 274.
# 🔍 BLASTing row 275...
# ✅ Match(es) found: sp|B1M0M1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 276...
# ❌ No Methylobacterium match found in row 276.
# 🔍 BLASTing row 277...
# ❌ No Methylobacterium match found in row 277.
# 🔍 BLASTing row 278...
# ✅ Match(es) found: sp|B8IKN3.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWN6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 279...
# ✅ Match(es) found: sp|B8IKN3.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWN6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 280...
# ❌ No Methylobacterium match found in row 280.
# 🔍 BLASTing row 281...
# ⚠️ Skipping row 281 — no sequence available.
# 🔍 BLASTing row 282...
# ❌ No Methylobacterium match found in row 282.
# 🔍 BLASTing row 283...
# ✅ Match(es) found: sp|B0UN04.1| [Methylobacterium sp. 4-46] & sp|B8IRU5.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 284...
# ❌ No Methylobacterium match found in row 284.
# 🔍 BLASTing row 285...
# ✅ Match(es) found: sp|B1LXZ1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UB90.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 286...
# ❌ No Methylobacterium match found in row 286.
# 🔍 BLASTing row 287...
# ❌ No Methylobacterium match found in row 287.
# 🔍 BLASTing row 288...
# ❌ No Methylobacterium match found in row 288.
# 🔍 BLASTing row 289...
# ❌ No Methylobacterium match found in row 289.
# 🔍 BLASTing row 290...
# ❌ No Methylobacterium match found in row 290.
# 🔍 BLASTing row 291...
# ❌ No Methylobacterium match found in row 291.
# 🔍 BLASTing row 292...
# ❌ No Methylobacterium match found in row 292.
# 🔍 BLASTing row 293...
# ❌ No Methylobacterium match found in row 293.
# 🔍 BLASTing row 294...
# ❌ No Methylobacterium match found in row 294.
# 🔍 BLASTing row 295...
# ✅ Match(es) found: sp|B1M0N0.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UGC4.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 296...
# ❌ No Methylobacterium match found in row 296.
# 🔍 BLASTing row 297...
# ❌ No Methylobacterium match found in row 297.
# 🔍 BLASTing row 298...
# ❌ No Methylobacterium match found in row 298.
# 🔍 BLASTing row 299...
# ❌ No Methylobacterium match found in row 299.
# 🔍 BLASTing row 300...
# ❌ No Methylobacterium match found in row 300.
# 🔍 BLASTing row 301...
# ❌ No Methylobacterium match found in row 301.
# 🔍 BLASTing row 302...
# ❌ No Methylobacterium match found in row 302.
# 🔍 BLASTing row 303...
# ❌ No Methylobacterium match found in row 303.
# 🔍 BLASTing row 304...
# ❌ No Methylobacterium match found in row 304.
# 🔍 BLASTing row 305...
# ❌ No Methylobacterium match found in row 305.
# 🔍 BLASTing row 306...
# ❌ No Methylobacterium match found in row 306.
# 🔍 BLASTing row 307...
# ❌ No Methylobacterium match found in row 307.
# 🔍 BLASTing row 308...
# ❌ No Methylobacterium match found in row 308.
# 🔍 BLASTing row 309...
# ❌ No Methylobacterium match found in row 309.
# 🔍 BLASTing row 310...
# ❌ No Methylobacterium match found in row 310.
# 🔍 BLASTing row 311...
# ❌ No Methylobacterium match found in row 311.
# 🔍 BLASTing row 312...
# ✅ Match(es) found: sp|B8IRY2.1| [NADPH] hemoprotein beta-component; Short=SiR-HP; Short=SiRHP [Methylobacterium nodulans ORS 2060] & sp|B1LS97.1| [NADPH] hemoprotein beta-component; Short=SiR-HP; Short=SiRHP [Methylobacterium radiotolerans JCM 2831] & sp|B0U8Y9.1| [NADPH] hemoprotein beta-component; Short=SiR-HP; Short=SiRHP [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 313...
# ❌ No Methylobacterium match found in row 313.
# 🔍 BLASTing row 314...
# ❌ No Methylobacterium match found in row 314.
# 🔍 BLASTing row 315...
# ❌ No Methylobacterium match found in row 315.
# 🔍 BLASTing row 316...
# ❌ No Methylobacterium match found in row 316.
# 🔍 BLASTing row 317...
# ❌ No Methylobacterium match found in row 317.
# 🔍 BLASTing row 318...
# ❌ No Methylobacterium match found in row 318.
# 🔍 BLASTing row 319...
# ❌ No Methylobacterium match found in row 319.
# 🔍 BLASTing row 320...
# ❌ No Methylobacterium match found in row 320.
# 🔍 BLASTing row 321...
# ❌ No Methylobacterium match found in row 321.
# 🔍 BLASTing row 322...
# ❌ No Methylobacterium match found in row 322.
# 🔍 BLASTing row 323...
# ✅ Match(es) found: sp|B8IPW1.1| [Methylobacterium nodulans ORS 2060] & sp|B0UKV2.1| [Methylobacterium sp. 4-46] & sp|B1LSQ8.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 324...
# ✅ Match(es) found: sp|B0UIA8.1| [Methylobacterium sp. 4-46] & sp|B8I9V8.1| [Methylobacterium nodulans ORS 2060] & sp|B1LSI6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 325...
# ✅ Match(es) found: sp|B0UFS2.1| [Methylobacterium sp. 4-46] & sp|B1M595.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8I9Q3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 326...
# ❌ No Methylobacterium match found in row 326.
# 🔍 BLASTing row 327...
# ❌ No Methylobacterium match found in row 327.
# 🔍 BLASTing row 328...
# ❌ No Methylobacterium match found in row 328.
# 🔍 BLASTing row 329...
# ❌ No Methylobacterium match found in row 329.
# 🔍 BLASTing row 330...
# ❌ No Methylobacterium match found in row 330.
# 🔍 BLASTing row 331...
# ❌ No Methylobacterium match found in row 331.
# 🔍 BLASTing row 332...
# ❌ No Methylobacterium match found in row 332.
# 🔍 BLASTing row 333...
# ❌ No Methylobacterium match found in row 333.
# 🔍 BLASTing row 334...
# ✅ Match(es) found: sp|B8IMY6.1| [acyl-carrier-protein] synthase; Short=Holo-ACP synthase; AltName: Full=4'-phosphopantetheinyl transferase AcpS [Methylobacterium nodulans ORS 2060] & sp|B1LTR5.1| [acyl-carrier-protein] synthase; Short=Holo-ACP synthase; AltName: Full=4'-phosphopantetheinyl transferase AcpS [Methylobacterium radiotolerans JCM 2831] & sp|B0UE20.1| [acyl-carrier-protein] synthase; Short=Holo-ACP synthase; AltName: Full=4'-phosphopantetheinyl transferase AcpS [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 335...
# ❌ No Methylobacterium match found in row 335.
# 🔍 BLASTing row 336...
# ❌ No Methylobacterium match found in row 336.
# 🔍 BLASTing row 337...
# ✅ Match(es) found: sp|B8IPH3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 338...
# ✅ Match(es) found: sp|B8IPH4.1| [(5-phosphoribosylamino)methylideneamino] imidazole-4-carboxamide isomerase; AltName: Full=Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [Methylobacterium nodulans ORS 2060] & sp|B0UHR6.1| [(5-phosphoribosylamino)methylideneamino] imidazole-4-carboxamide isomerase; AltName: Full=Phosphoribosylformimino-5-aminoimidazole carboxamide ribotide isomerase [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 339...
# ✅ Match(es) found: sp|B1LU98.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 340...
# ❌ No Methylobacterium match found in row 340.
# 🔍 BLASTing row 341...
# ✅ Match(es) found: sp|B1M3B2.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 342...
# ❌ No Methylobacterium match found in row 342.
# 🔍 BLASTing row 343...
# ❌ No Methylobacterium match found in row 343.
# 🔍 BLASTing row 344...
# ❌ No Methylobacterium match found in row 344.
# 🔍 BLASTing row 345...
# ❌ No Methylobacterium match found in row 345.
# 🔍 BLASTing row 346...
# ❌ No Methylobacterium match found in row 346.
# 🔍 BLASTing row 347...
# ❌ No Methylobacterium match found in row 347.
# 🔍 BLASTing row 348...
# ❌ No Methylobacterium match found in row 348.
# 🔍 BLASTing row 349...
# ❌ No Methylobacterium match found in row 349.
# 🔍 BLASTing row 350...
# ❌ No Methylobacterium match found in row 350.
# 🔍 BLASTing row 351...
# ✅ Match(es) found: sp|B1M4N1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IFR7.1| [Methylobacterium nodulans ORS 2060] & sp|B0UP55.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 352...
# ✅ Match(es) found: sp|B1M4N1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IFR7.1| [Methylobacterium nodulans ORS 2060] & sp|B0UP55.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 353...
# ❌ No Methylobacterium match found in row 353.
# 🔍 BLASTing row 354...
# ❌ No Methylobacterium match found in row 354.
# 🔍 BLASTing row 355...
# ✅ Match(es) found: sp|B8IHS8.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 356...
# ✅ Match(es) found: sp|B8IHS8.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 357...
# ❌ No Methylobacterium match found in row 357.
# 🔍 BLASTing row 358...
# ❌ No Methylobacterium match found in row 358.
# 🔍 BLASTing row 359...
# ❌ No Methylobacterium match found in row 359.
# 🔍 BLASTing row 360...
# ❌ No Methylobacterium match found in row 360.
# 🔍 BLASTing row 361...
# ❌ No Methylobacterium match found in row 361.
# 🔍 BLASTing row 362...
# ❌ No Methylobacterium match found in row 362.
# 🔍 BLASTing row 363...
# ❌ No Methylobacterium match found in row 363.
# 🔍 BLASTing row 364...
# ❌ No Methylobacterium match found in row 364.
# 🔍 BLASTing row 365...
# ❌ No Methylobacterium match found in row 365.
# 🔍 BLASTing row 366...
# ❌ No Methylobacterium match found in row 366.
# 🔍 BLASTing row 367...
# ❌ No Methylobacterium match found in row 367.
# 🔍 BLASTing row 368...
# ❌ No Methylobacterium match found in row 368.
# 🔍 BLASTing row 369...
# ✅ Match(es) found: sp|B0UJH5.1| [Methylobacterium sp. 4-46] & sp|B8IHY5.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 370...
# ❌ No Methylobacterium match found in row 370.
# 🔍 BLASTing row 371...
# ❌ No Methylobacterium match found in row 371.
# 🔍 BLASTing row 372...
# ✅ Match(es) found: sp|B8IBW2.1| [Methylobacterium nodulans ORS 2060] & sp|B1LYP9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UKC8.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 373...
# ✅ Match(es) found: sp|B8IBW2.1| [Methylobacterium nodulans ORS 2060] & sp|B1LYP9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UKC8.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 374...
# ✅ Match(es) found: sp|B1LUQ0.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IH95.1| [Methylobacterium nodulans ORS 2060] & sp|B0UL80.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 375...
# ❌ No Methylobacterium match found in row 375.
# 🔍 BLASTing row 376...
# ✅ Match(es) found: sp|B1LZ88.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UML5.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 377...
# ❌ No Methylobacterium match found in row 377.
# 🔍 BLASTing row 378...
# ❌ No Methylobacterium match found in row 378.
# 🔍 BLASTing row 379...
# ❌ No Methylobacterium match found in row 379.
# 🔍 BLASTing row 380...
# ❌ No Methylobacterium match found in row 380.
# 🔍 BLASTing row 381...
# ❌ No Methylobacterium match found in row 381.
# 🔍 BLASTing row 382...
# ❌ No Methylobacterium match found in row 382.
# 🔍 BLASTing row 383...
# ❌ No Methylobacterium match found in row 383.
# 🔍 BLASTing row 384...
# ❌ No Methylobacterium match found in row 384.
# 🔍 BLASTing row 385...
# ❌ No Methylobacterium match found in row 385.
# 🔍 BLASTing row 386...
# ❌ No Methylobacterium match found in row 386.
# 🔍 BLASTing row 387...
# ❌ No Methylobacterium match found in row 387.
# 🔍 BLASTing row 388...
# ❌ No Methylobacterium match found in row 388.
# 🔍 BLASTing row 389...
# ❌ No Methylobacterium match found in row 389.
# 🔍 BLASTing row 390...
# ❌ No Methylobacterium match found in row 390.
# 🔍 BLASTing row 391...
# ❌ No Methylobacterium match found in row 391.
# 🔍 BLASTing row 392...
# ❌ No Methylobacterium match found in row 392.
# 🔍 BLASTing row 393...
# ❌ No Methylobacterium match found in row 393.
# 🔍 BLASTing row 394...
# ❌ No Methylobacterium match found in row 394.
# 🔍 BLASTing row 395...
# ❌ No Methylobacterium match found in row 395.
# 🔍 BLASTing row 396...
# ❌ No Methylobacterium match found in row 396.
# 🔍 BLASTing row 397...
# ❌ No Methylobacterium match found in row 397.
# 🔍 BLASTing row 398...
# ❌ No Methylobacterium match found in row 398.
# 🔍 BLASTing row 399...
# ❌ No Methylobacterium match found in row 399.
# 🔍 BLASTing row 400...
# ❌ No Methylobacterium match found in row 400.
# 🔍 BLASTing row 401...
# ❌ No Methylobacterium match found in row 401.
# 🔍 BLASTing row 402...
# ✅ Match(es) found: sp|B8IRX8.1| [Methylobacterium nodulans ORS 2060] & sp|B0U8Y5.1| [Methylobacterium sp. 4-46] & sp|B1LSA1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 403...
# ❌ No Methylobacterium match found in row 403.
# 🔍 BLASTing row 404...
# ❌ No Methylobacterium match found in row 404.
# 🔍 BLASTing row 405...
# ✅ Match(es) found: sp|B0ULF6.1| [Methylobacterium sp. 4-46] & sp|B8ID24.1| [Methylobacterium nodulans ORS 2060] & sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 406...
# ✅ Match(es) found: sp|B1M4N1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IFR7.1| [Methylobacterium nodulans ORS 2060] & sp|B0UP55.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 407...
# ❌ No Methylobacterium match found in row 407.
# 🔍 BLASTing row 408...
# ❌ No Methylobacterium match found in row 408.
# 🔍 BLASTing row 409...
# ❌ No Methylobacterium match found in row 409.
# 🔍 BLASTing row 410...
# ❌ No Methylobacterium match found in row 410.
# 🔍 BLASTing row 411...
# ❌ No Methylobacterium match found in row 411.
# 🔍 BLASTing row 412...
# ❌ No Methylobacterium match found in row 412.
# 🔍 BLASTing row 413...
# ❌ No Methylobacterium match found in row 413.
# 🔍 BLASTing row 414...
# ❌ No Methylobacterium match found in row 414.
# 🔍 BLASTing row 415...
# ❌ No Methylobacterium match found in row 415.
# 🔍 BLASTing row 416...
# ❌ No Methylobacterium match found in row 416.
# 🔍 BLASTing row 417...
# ❌ No Methylobacterium match found in row 417.
# 🔍 BLASTing row 418...
# ❌ No Methylobacterium match found in row 418.
# 🔍 BLASTing row 419...
# ❌ No Methylobacterium match found in row 419.
# 🔍 BLASTing row 420...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 421...
# ✅ Match(es) found: sp|B8IEC7.1| [Methylobacterium nodulans ORS 2060] & sp|B0UL34.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 422...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 423...
# ❌ No Methylobacterium match found in row 423.
# 🔍 BLASTing row 424...
# ❌ No Methylobacterium match found in row 424.
# 🔍 BLASTing row 425...
# ✅ Match(es) found: sp|B1LTP6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 426...
# ❌ No Methylobacterium match found in row 426.
# 🔍 BLASTing row 427...
# ❌ No Methylobacterium match found in row 427.
# 🔍 BLASTing row 428...
# ✅ Match(es) found: sp|B1LXK9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 429...
# ✅ Match(es) found: sp|B1LZS5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 430...
# ✅ Match(es) found: sp|B1LZS5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 431...
# ❌ No Methylobacterium match found in row 431.
# 🔍 BLASTing row 432...
# ❌ No Methylobacterium match found in row 432.
# 🔍 BLASTing row 433...
# ❌ No Methylobacterium match found in row 433.
# 🔍 BLASTing row 434...
# ✅ Match(es) found: sp|B1LVC3.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 435...
# ✅ Match(es) found: sp|B0UCI8.1| [Methylobacterium sp. 4-46] & sp|B8I9H6.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 436...
# ❌ No Methylobacterium match found in row 436.
# 🔍 BLASTing row 437...
# ❌ No Methylobacterium match found in row 437.
# 🔍 BLASTing row 438...
# ✅ Match(es) found: sp|B0UFH5.1| [Methylobacterium sp. 4-46] & sp|B1LXZ8.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IMW7.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 439...
# ❌ No Methylobacterium match found in row 439.
# 🔍 BLASTing row 440...
# ✅ Match(es) found: sp|B8IN64.1| [Methylobacterium nodulans ORS 2060] & sp|B1LXZ4.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UFC7.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 441...
# ✅ Match(es) found: sp|B8IN64.1| [Methylobacterium nodulans ORS 2060] & sp|B1LXZ4.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UFC7.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 442...
# ✅ Match(es) found: sp|B1LXZ3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UFC6.1| [Methylobacterium sp. 4-46] & sp|B8IN63.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 443...
# ✅ Match(es) found: sp|B1LXZ3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IN63.1| [Methylobacterium nodulans ORS 2060] & sp|B0UFC6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 444...
# ✅ Match(es) found: sp|B1LXZ1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UB90.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 445...
# ✅ Match(es) found: sp|B0UQ04.1| [acyl-carrier-protein] dehydratase FabZ; AltName: Full=(3R)-hydroxymyristoyl-[acyl-carrier-protein] dehydratase; Short=(3R)-hydroxymyristoyl-ACP dehydrase; AltName: Full=Beta-hydroxyacyl-ACP dehydratase [Methylobacterium sp. 4-46] & sp|B8INJ5.1| [acyl-carrier-protein] dehydratase FabZ; AltName: Full=(3R)-hydroxymyristoyl-[acyl-carrier-protein] dehydratase; Short=(3R)-hydroxymyristoyl-ACP dehydrase; AltName: Full=Beta-hydroxyacyl-ACP dehydratase [Methylobacterium nodulans ORS 2060] & sp|B1LTP5.1| [acyl-carrier-protein] dehydratase FabZ; AltName: Full=(3R)-hydroxymyristoyl-[acyl-carrier-protein] dehydratase; Short=(3R)-hydroxymyristoyl-ACP dehydrase; AltName: Full=Beta-hydroxyacyl-ACP dehydratase [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 446...
# ❌ No Methylobacterium match found in row 446.
# 🔍 BLASTing row 447...
# ❌ No Methylobacterium match found in row 447.
# 🔍 BLASTing row 448...
# ❌ No Methylobacterium match found in row 448.
# 🔍 BLASTing row 449...
# ❌ No Methylobacterium match found in row 449.
# 🔍 BLASTing row 450...
# ❌ No Methylobacterium match found in row 450.
# 🔍 BLASTing row 451...
# ❌ No Methylobacterium match found in row 451.
# 🔍 BLASTing row 452...
# ❌ No Methylobacterium match found in row 452.
# 🔍 BLASTing row 453...
# ❌ No Methylobacterium match found in row 453.
# 🔍 BLASTing row 454...
# ❌ No Methylobacterium match found in row 454.
# 🔍 BLASTing row 455...
# ✅ Match(es) found: sp|B0UIA8.1| [Methylobacterium sp. 4-46] & sp|B8I9V8.1| [Methylobacterium nodulans ORS 2060] & sp|B1LSI6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 456...
# ❌ No Methylobacterium match found in row 456.
# 🔍 BLASTing row 457...
# ❌ No Methylobacterium match found in row 457.
# 🔍 BLASTing row 458...
# ❌ No Methylobacterium match found in row 458.
# 🔍 BLASTing row 459...
# ❌ No Methylobacterium match found in row 459.
# 🔍 BLASTing row 460...
# ❌ No Methylobacterium match found in row 460.
# 🔍 BLASTing row 461...
# ✅ Match(es) found: sp|B8ID24.1| [Methylobacterium nodulans ORS 2060] & sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 462...
# ✅ Match(es) found: sp|B8ID24.1| [Methylobacterium nodulans ORS 2060] & sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 463...
# ✅ Match(es) found: sp|B8ID24.1| [Methylobacterium nodulans ORS 2060] & sp|B1M3G3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0ULF6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 464...
# ❌ No Methylobacterium match found in row 464.
# 🔍 BLASTing row 465...
# ❌ No Methylobacterium match found in row 465.
# 🔍 BLASTing row 466...
# ❌ No Methylobacterium match found in row 466.
# 🔍 BLASTing row 467...
# ❌ No Methylobacterium match found in row 467.
# 🔍 BLASTing row 468...
# ❌ No Methylobacterium match found in row 468.
# 🔍 BLASTing row 469...
# ✅ Match(es) found: sp|B1LVX5.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UNK9.2| [Methylobacterium sp. 4-46] & sp|B8ICG5.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 470...
# ❌ No Methylobacterium match found in row 470.
# 🔍 BLASTing row 471...
# ❌ No Methylobacterium match found in row 471.
# 🔍 BLASTing row 472...
# ❌ No Methylobacterium match found in row 472.
# 🔍 BLASTing row 473...
# ❌ No Methylobacterium match found in row 473.
# 🔍 BLASTing row 474...
# ❌ No Methylobacterium match found in row 474.
# 🔍 BLASTing row 475...
# ✅ Match(es) found: sp|B8IJ00.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 476...
# ✅ Match(es) found: sp|B8IJ00.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 477...
# ✅ Match(es) found: sp|B1LTL1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UQT7.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 478...
# ❌ No Methylobacterium match found in row 478.
# 🔍 BLASTing row 479...
# ❌ No Methylobacterium match found in row 479.
# 🔍 BLASTing row 480...
# ✅ Match(es) found: sp|B8IGX3.1| [Methylobacterium nodulans ORS 2060] & sp|B0UEX5.1| [Methylobacterium sp. 4-46] & sp|B1LZQ1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 481...
# ❌ No Methylobacterium match found in row 481.
# 🔍 BLASTing row 482...
# ❌ No Methylobacterium match found in row 482.
# 🔍 BLASTing row 483...
# ❌ No Methylobacterium match found in row 483.
# 🔍 BLASTing row 484...
# ❌ No Methylobacterium match found in row 484.
# 🔍 BLASTing row 485...
# ❌ No Methylobacterium match found in row 485.
# 🔍 BLASTing row 486...
# ✅ Match(es) found: sp|B0UPC4.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 487...
# ❌ No Methylobacterium match found in row 487.
# 🔍 BLASTing row 488...
# ❌ No Methylobacterium match found in row 488.
# 🔍 BLASTing row 489...
# ❌ No Methylobacterium match found in row 489.
# 🔍 BLASTing row 490...
# ❌ No Methylobacterium match found in row 490.
# 🔍 BLASTing row 491...
# ❌ No Methylobacterium match found in row 491.
# 🔍 BLASTing row 492...
# ✅ Match(es) found: sp|B0UM37.1| [Methylobacterium sp. 4-46] & sp|B8IPU4.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 493...
# ❌ No Methylobacterium match found in row 493.
# 🔍 BLASTing row 494...
# ✅ Match(es) found: sp|B1M325.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UJB1.1| [Methylobacterium sp. 4-46] & sp|B8IS51.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 495...
# ❌ No Methylobacterium match found in row 495.
# 🔍 BLASTing row 496...
# ❌ No Methylobacterium match found in row 496.
# 🔍 BLASTing row 497...
# ❌ No Methylobacterium match found in row 497.
# 🔍 BLASTing row 498...
# ❌ No Methylobacterium match found in row 498.
# 🔍 BLASTing row 499...
# ❌ No Methylobacterium match found in row 499.
# 🔍 BLASTing row 500...
# ❌ No Methylobacterium match found in row 500.
# 🔍 BLASTing row 501...
# ❌ No Methylobacterium match found in row 501.
# 🔍 BLASTing row 502...
# ❌ No Methylobacterium match found in row 502.
# 🔍 BLASTing row 503...
# ❌ No Methylobacterium match found in row 503.
# 🔍 BLASTing row 504...
# ❌ No Methylobacterium match found in row 504.
# 🔍 BLASTing row 505...
# ✅ Match(es) found: sp|B8IHS8.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 506...
# ✅ Match(es) found: sp|B8IHS8.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 507...
# ✅ Match(es) found: sp|B1LTD9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B1LW44.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 508...
# ❌ No Methylobacterium match found in row 508.
# 🔍 BLASTing row 509...
# ❌ No Methylobacterium match found in row 509.
# 🔍 BLASTing row 510...
# ✅ Match(es) found: sp|B1LTD9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 511...
# ❌ No Methylobacterium match found in row 511.
# 🔍 BLASTing row 512...
# ❌ No Methylobacterium match found in row 512.
# 🔍 BLASTing row 513...
# ❌ No Methylobacterium match found in row 513.
# 🔍 BLASTing row 514...
# ❌ No Methylobacterium match found in row 514.
# 🔍 BLASTing row 515...
# ❌ No Methylobacterium match found in row 515.
# 🔍 BLASTing row 516...
# ✅ Match(es) found: sp|B1LXZ3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UFC6.1| [Methylobacterium sp. 4-46] & sp|B8IN63.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 517...
# ✅ Match(es) found: sp|B0U7Z5.1| [Methylobacterium sp. 4-46] & sp|B8IP99.1| [Methylobacterium nodulans ORS 2060] & sp|B1M5Q2.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 518...
# ❌ No Methylobacterium match found in row 518.
# 🔍 BLASTing row 519...
# ❌ No Methylobacterium match found in row 519.
# 🔍 BLASTing row 520...
# ❌ No Methylobacterium match found in row 520.
# 🔍 BLASTing row 521...
# ❌ No Methylobacterium match found in row 521.
# 🔍 BLASTing row 522...
# ✅ Match(es) found: sp|B8IP92.1| [Methylobacterium nodulans ORS 2060] & sp|B1M5Q9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0U802.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 523...
# ❌ No Methylobacterium match found in row 523.
# 🔍 BLASTing row 524...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWQ5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 525...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060] & sp|B1LWQ5.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 526...
# ✅ Match(es) found: sp|B0U8N5.1| [Methylobacterium sp. 4-46] & sp|B1LXF3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IGT3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 527...
# ✅ Match(es) found: sp|B0U8N5.1| [Methylobacterium sp. 4-46] & sp|B1LXF3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IGT3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 528...
# ✅ Match(es) found: sp|B0U8N5.1| [Methylobacterium sp. 4-46] & sp|B1LXF3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IGT3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 529...
# ✅ Match(es) found: sp|B0U8N5.1| [Methylobacterium sp. 4-46] & sp|B1LXF3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IGT3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 530...
# ✅ Match(es) found: sp|B0U8N5.1| [Methylobacterium sp. 4-46] & sp|B1LXF3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IGT3.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 531...
# ❌ No Methylobacterium match found in row 531.
# 🔍 BLASTing row 532...
# ✅ Match(es) found: sp|B0UCI8.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 533...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 534...
# ❌ No Methylobacterium match found in row 534.
# 🔍 BLASTing row 535...
# ✅ Match(es) found: sp|B1M1K0.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UJ78.1| [Methylobacterium sp. 4-46] & sp|B8IPM5.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 536...
# ❌ No Methylobacterium match found in row 536.
# 🔍 BLASTing row 537...
# ❌ No Methylobacterium match found in row 537.
# 🔍 BLASTing row 538...
# ❌ No Methylobacterium match found in row 538.
# 🔍 BLASTing row 539...
# ❌ No Methylobacterium match found in row 539.
# 🔍 BLASTing row 540...
# ❌ No Methylobacterium match found in row 540.
# 🔍 BLASTing row 541...
# ❌ No Methylobacterium match found in row 541.
# 🔍 BLASTing row 542...
# ❌ No Methylobacterium match found in row 542.
# 🔍 BLASTing row 543...
# ❌ No Methylobacterium match found in row 543.
# 🔍 BLASTing row 544...
# ❌ No Methylobacterium match found in row 544.
# 🔍 BLASTing row 545...
# ❌ No Methylobacterium match found in row 545.
# 🔍 BLASTing row 546...
# ❌ No Methylobacterium match found in row 546.
# ...
# 🔍 BLASTing row 702...
# ❌ No Methylobacterium match found in row 702.
# 🔍 BLASTing row 703...
# ❌ No Methylobacterium match found in row 703.
# 🔍 BLASTing row 704...
# ❌ No Methylobacterium match found in row 704.
# 🔍 BLASTing row 705...
# ✅ Match(es) found: sp|B0UBD4.1| [Methylobacterium sp. 4-46] & sp|B1M6A7.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 706...
# ❌ No Methylobacterium match found in row 706.
# 🔍 BLASTing row 707...
# ❌ No Methylobacterium match found in row 707.
# 🔍 BLASTing row 708...
# ❌ No Methylobacterium match found in row 708.
# 🔍 BLASTing row 709...
# ❌ No Methylobacterium match found in row 709.
# 🔍 BLASTing row 710...
# ❌ No Methylobacterium match found in row 710.
# 🔍 BLASTing row 711...
# ❌ No Methylobacterium match found in row 711.
# 🔍 BLASTing row 712...
# ❌ No Methylobacterium match found in row 712.
# 🔍 BLASTing row 713...
# ❌ No Methylobacterium match found in row 713.
# 🔍 BLASTing row 714...
# ❌ No Methylobacterium match found in row 714.
# 🔍 BLASTing row 715...
# ❌ No Methylobacterium match found in row 715.
# 🔍 BLASTing row 716...
# ❌ No Methylobacterium match found in row 716.
# 🔍 BLASTing row 717...
# ❌ No Methylobacterium match found in row 717.
# 🔍 BLASTing row 718...
# ❌ No Methylobacterium match found in row 718.
# 🔍 BLASTing row 719...
# ❌ No Methylobacterium match found in row 719.
# 🔍 BLASTing row 720...
# ❌ No Methylobacterium match found in row 720.
# 🔍 BLASTing row 721...
# ❌ No Methylobacterium match found in row 721.
# 🔍 BLASTing row 722...
# ❌ No Methylobacterium match found in row 722.
# 🔍 BLASTing row 723...
# ❌ No Methylobacterium match found in row 723.
# 🔍 BLASTing row 724...
# ❌ No Methylobacterium match found in row 724.
# 🔍 BLASTing row 725...
# ❌ No Methylobacterium match found in row 725.
# 🔍 BLASTing row 726...
# ❌ No Methylobacterium match found in row 726.
# 🔍 BLASTing row 727...
# ❌ No Methylobacterium match found in row 727.
# 🔍 BLASTing row 728...
# ❌ No Methylobacterium match found in row 728.
# 🔍 BLASTing row 729...
# ❌ No Methylobacterium match found in row 729.
# 🔍 BLASTing row 730...
# ❌ No Methylobacterium match found in row 730.
# 🔍 BLASTing row 731...
# ❌ No Methylobacterium match found in row 731.
# 🔍 BLASTing row 732...
# ❌ No Methylobacterium match found in row 732.
# 🔍 BLASTing row 733...
# ❌ No Methylobacterium match found in row 733.
# 🔍 BLASTing row 734...
# ❌ No Methylobacterium match found in row 734.
# 🔍 BLASTing row 735...
# ❌ No Methylobacterium match found in row 735.
# 🔍 BLASTing row 736...
# ❌ No Methylobacterium match found in row 736.
# 🔍 BLASTing row 737...
# ❌ No Methylobacterium match found in row 737.
# 🔍 BLASTing row 738...
# ❌ No Methylobacterium match found in row 738.
# 🔍 BLASTing row 739...
# ❌ No Methylobacterium match found in row 739.
# 🔍 BLASTing row 740...
# ❌ No Methylobacterium match found in row 740.
# 🔍 BLASTing row 741...
# ❌ No Methylobacterium match found in row 741.
# 🔍 BLASTing row 742...
# ❌ No Methylobacterium match found in row 742.
# 🔍 BLASTing row 743...
# ❌ No Methylobacterium match found in row 743.
# 🔍 BLASTing row 744...
# ❌ No Methylobacterium match found in row 744.
# 🔍 BLASTing row 745...
# ❌ No Methylobacterium match found in row 745.
# 🔍 BLASTing row 746...
# ❌ No Methylobacterium match found in row 746.
# 🔍 BLASTing row 747...
# ❌ No Methylobacterium match found in row 747.
# 🔍 BLASTing row 748...
# ❌ No Methylobacterium match found in row 748.
# 🔍 BLASTing row 749...
# ❌ No Methylobacterium match found in row 749.
# 🔍 BLASTing row 750...
# ❌ No Methylobacterium match found in row 750.
# 🔍 BLASTing row 751...
# ❌ No Methylobacterium match found in row 751.
# 🔍 BLASTing row 752...
# ❌ No Methylobacterium match found in row 752.
# 🔍 BLASTing row 753...
# ❌ No Methylobacterium match found in row 753.
# 🔍 BLASTing row 754...
# ❌ No Methylobacterium match found in row 754.
# 🔍 BLASTing row 755...
# ❌ No Methylobacterium match found in row 755.
# 🔍 BLASTing row 756...
# ❌ No Methylobacterium match found in row 756.
# 🔍 BLASTing row 757...
# ❌ No Methylobacterium match found in row 757.
# 🔍 BLASTing row 758...
# ❌ No Methylobacterium match found in row 758.
# 🔍 BLASTing row 759...
# ❌ No Methylobacterium match found in row 759.
# 🔍 BLASTing row 760...
# ❌ No Methylobacterium match found in row 760.
# 🔍 BLASTing row 761...
# ❌ No Methylobacterium match found in row 761.
# 🔍 BLASTing row 762...
# ❌ No Methylobacterium match found in row 762.
# 🔍 BLASTing row 763...
# ❌ No Methylobacterium match found in row 763.
# 🔍 BLASTing row 764...
# ❌ No Methylobacterium match found in row 764.
# 🔍 BLASTing row 765...
# ❌ No Methylobacterium match found in row 765.
# 🔍 BLASTing row 766...
# ❌ No Methylobacterium match found in row 766.
# 🔍 BLASTing row 767...
# ❌ No Methylobacterium match found in row 767.
# 🔍 BLASTing row 768...
# ✅ Match(es) found: sp|B0UBU9.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 769...
# ❌ No Methylobacterium match found in row 769.
# 🔍 BLASTing row 770...
# ❌ No Methylobacterium match found in row 770.
# 🔍 BLASTing row 771...
# ❌ No Methylobacterium match found in row 771.
# 🔍 BLASTing row 772...
# ❌ No Methylobacterium match found in row 772.
# 🔍 BLASTing row 773...
# ❌ No Methylobacterium match found in row 773.
# 🔍 BLASTing row 774...
# ❌ No Methylobacterium match found in row 774.
# 🔍 BLASTing row 775...
# ❌ No Methylobacterium match found in row 775.
# 🔍 BLASTing row 776...
# ❌ No Methylobacterium match found in row 776.
# 🔍 BLASTing row 777...
# ✅ Match(es) found: sp|B1M0D1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UQF5.1| [Methylobacterium sp. 4-46] & sp|B8IBS4.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 778...
# ❌ No Methylobacterium match found in row 778.
# 🔍 BLASTing row 779...
# ❌ No Methylobacterium match found in row 779.
# 🔍 BLASTing row 780...
# ✅ Match(es) found: sp|B0UKC4.1| [Methylobacterium sp. 4-46] & sp|B8IP71.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 781...
# ❌ No Methylobacterium match found in row 781.
# 🔍 BLASTing row 782...
# ❌ No Methylobacterium match found in row 782.
# 🔍 BLASTing row 783...
# ❌ No Methylobacterium match found in row 783.
# 🔍 BLASTing row 784...
# ❌ No Methylobacterium match found in row 784.
# 🔍 BLASTing row 785...
# ❌ No Methylobacterium match found in row 785.
# 🔍 BLASTing row 786...
# ❌ No Methylobacterium match found in row 786.
# 🔍 BLASTing row 787...
# ❌ No Methylobacterium match found in row 787.
# 🔍 BLASTing row 788...
# ⚠️ Skipping row 788 — no sequence available.
# 🔍 BLASTing row 789...
# ❌ No Methylobacterium match found in row 789.
# 🔍 BLASTing row 790...
# ❌ No Methylobacterium match found in row 790.
# 🔍 BLASTing row 791...
# ❌ No Methylobacterium match found in row 791.
# 🔍 BLASTing row 792...
# ❌ No Methylobacterium match found in row 792.
# 🔍 BLASTing row 793...
# ❌ No Methylobacterium match found in row 793.
# 🔍 BLASTing row 794...
# ❌ No Methylobacterium match found in row 794.
# 🔍 BLASTing row 795...
# ✅ Match(es) found: sp|B1LUA2.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IPH3.1| [Methylobacterium nodulans ORS 2060] & sp|B0UHR5.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 796...
# ❌ No Methylobacterium match found in row 796.
# 🔍 BLASTing row 797...
# ❌ No Methylobacterium match found in row 797.
# 🔍 BLASTing row 798...
# ❌ No Methylobacterium match found in row 798.
# 🔍 BLASTing row 799...
# ❌ No Methylobacterium match found in row 799.
# 🔍 BLASTing row 800...
# ❌ No Methylobacterium match found in row 800.
# 🔍 BLASTing row 801...
# ❌ No Methylobacterium match found in row 801.
# 🔍 BLASTing row 802...
# ✅ Match(es) found: sp|B8IPK9.1| [Methylobacterium nodulans ORS 2060] & sp|B0UJ62.1| [Methylobacterium sp. 4-46] & sp|B1LYS1.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 803...
# ✅ Match(es) found: sp|B1LTP6.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 804...
# ❌ No Methylobacterium match found in row 804.
# 🔍 BLASTing row 805...
# ❌ No Methylobacterium match found in row 805.
# 🔍 BLASTing row 806...
# ❌ No Methylobacterium match found in row 806.
# 🔍 BLASTing row 807...
# ❌ No Methylobacterium match found in row 807.
# 🔍 BLASTing row 808...
# ❌ No Methylobacterium match found in row 808.
# 🔍 BLASTing row 809...
# ✅ Match(es) found: sp|P15279.1| [cytochrome c] subunit 1; AltName: Full=MDH large subunit alpha; AltName: Full=MEDH; Flags: Precursor [Methylobacterium organophilum]
# 🔍 BLASTing row 810...
# ❌ No Methylobacterium match found in row 810.
# 🔍 BLASTing row 811...
# ❌ No Methylobacterium match found in row 811.
# 🔍 BLASTing row 812...
# ❌ No Methylobacterium match found in row 812.
# 🔍 BLASTing row 813...
# ❌ No Methylobacterium match found in row 813.
# 🔍 BLASTing row 814...
# ❌ No Methylobacterium match found in row 814.
# 🔍 BLASTing row 815...
# ✅ Match(es) found: sp|B1LXZ3.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IN63.1| [Methylobacterium nodulans ORS 2060] & sp|B0UFC6.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 816...
# ❌ No Methylobacterium match found in row 816.
# 🔍 BLASTing row 817...
# ❌ No Methylobacterium match found in row 817.
# 🔍 BLASTing row 818...
# ❌ No Methylobacterium match found in row 818.
# 🔍 BLASTing row 819...
# ❌ No Methylobacterium match found in row 819.
# 🔍 BLASTing row 820...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 821...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 822...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 823...
# ❌ No Methylobacterium match found in row 823.
# 🔍 BLASTing row 824...
# ❌ No Methylobacterium match found in row 824.
# 🔍 BLASTing row 825...
# ❌ No Methylobacterium match found in row 825.
# 🔍 BLASTing row 826...
# ❌ No Methylobacterium match found in row 826.
# 🔍 BLASTing row 827...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 828...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 829...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 830...
# ❌ No Methylobacterium match found in row 830.
# 🔍 BLASTing row 831...
# ✅ Match(es) found: sp|B1M4N1.1| [Methylobacterium radiotolerans JCM 2831] & sp|B8IFR7.1| [Methylobacterium nodulans ORS 2060] & sp|B0UP55.1| [Methylobacterium sp. 4-46]
# 🔍 BLASTing row 832...
# ❌ No Methylobacterium match found in row 832.
# 🔍 BLASTing row 833...
# ❌ No Methylobacterium match found in row 833.
# 🔍 BLASTing row 834...
# ❌ No Methylobacterium match found in row 834.
# 🔍 BLASTing row 835...
# ❌ No Methylobacterium match found in row 835.
# 🔍 BLASTing row 836...
# ❌ No Methylobacterium match found in row 836.
# 🔍 BLASTing row 837...
# ❌ No Methylobacterium match found in row 837.
# 🔍 BLASTing row 838...
# ❌ No Methylobacterium match found in row 838.
# 🔍 BLASTing row 839...
# ❌ No Methylobacterium match found in row 839.
# 🔍 BLASTing row 840...
# ❌ No Methylobacterium match found in row 840.
# 🔍 BLASTing row 841...
# ❌ No Methylobacterium match found in row 841.
# 🔍 BLASTing row 842...
# ❌ No Methylobacterium match found in row 842.
# 🔍 BLASTing row 843...
# ❌ No Methylobacterium match found in row 843.
# 🔍 BLASTing row 844...
# ❌ No Methylobacterium match found in row 844.
# 🔍 BLASTing row 845...
# ❌ No Methylobacterium match found in row 845.
# 🔍 BLASTing row 846...
# ❌ No Methylobacterium match found in row 846.
# 🔍 BLASTing row 847...
# ❌ No Methylobacterium match found in row 847.
# 🔍 BLASTing row 848...
# ❌ No Methylobacterium match found in row 848.
# 🔍 BLASTing row 849...
# ❌ No Methylobacterium match found in row 849.
# 🔍 BLASTing row 850...
# ❌ No Methylobacterium match found in row 850.
# 🔍 BLASTing row 851...
# ❌ No Methylobacterium match found in row 851.
# 🔍 BLASTing row 852...
# ❌ No Methylobacterium match found in row 852.
# 🔍 BLASTing row 853...
# ❌ No Methylobacterium match found in row 853.
# 🔍 BLASTing row 854...
# ❌ No Methylobacterium match found in row 854.
# 🔍 BLASTing row 855...
# ❌ No Methylobacterium match found in row 855.
# 🔍 BLASTing row 856...
# ✅ Match(es) found: sp|B0UAV0.1| [Methylobacterium sp. 4-46] & sp|B8IUB0.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 857...
# ❌ No Methylobacterium match found in row 857.
# 🔍 BLASTing row 858...
# ✅ Match(es) found: sp|B0UMS9.1| [Methylobacterium sp. 4-46] & sp|B8IEM1.1| [Methylobacterium nodulans ORS 2060] & sp|B1M695.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 859...
# ❌ No Methylobacterium match found in row 859.
# 🔍 BLASTing row 860...
# ❌ No Methylobacterium match found in row 860.
# 🔍 BLASTing row 861...
# ⚠️ Skipping row 861 — no sequence available.
# 🔍 BLASTing row 862...
# ✅ Match(es) found: sp|B1LTD9.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 863...
# ❌ No Methylobacterium match found in row 863.
# 🔍 BLASTing row 864...
# ❌ No Methylobacterium match found in row 864.
# 🔍 BLASTing row 865...
# ❌ No Methylobacterium match found in row 865.
# 🔍 BLASTing row 866...
# ✅ Match(es) found: sp|B0UBD4.1| [Methylobacterium sp. 4-46] & sp|B1M6A7.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 867...
# ❌ No Methylobacterium match found in row 867.
# 🔍 BLASTing row 868...
# ✅ Match(es) found: sp|B8IT32.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 869...
# ❌ No Methylobacterium match found in row 869.
# 🔍 BLASTing row 870...
# ❌ No Methylobacterium match found in row 870.
# 🔍 BLASTing row 871...
# ❌ No Methylobacterium match found in row 871.
# 🔍 BLASTing row 872...
# ❌ No Methylobacterium match found in row 872.
# 🔍 BLASTing row 873...
# ❌ No Methylobacterium match found in row 873.
# 🔍 BLASTing row 874...
# ❌ No Methylobacterium match found in row 874.
# 🔍 BLASTing row 875...
# ✅ Match(es) found: sp|B1LTD9.1| [Methylobacterium radiotolerans JCM 2831] & sp|B1LW44.1| [Methylobacterium radiotolerans JCM 2831]
# 🔍 BLASTing row 876...
# ❌ No Methylobacterium match found in row 876.
# 🔍 BLASTing row 877...
# ✅ Match(es) found: sp|B0UJH5.1| [Methylobacterium sp. 4-46] & sp|B8IHY5.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 878...
# ❌ No Methylobacterium match found in row 878.
# 🔍 BLASTing row 879...
# ❌ No Methylobacterium match found in row 879.
# 🔍 BLASTing row 880...
# ❌ No Methylobacterium match found in row 880.
# 🔍 BLASTing row 881...
# ❌ No Methylobacterium match found in row 881.
# 🔍 BLASTing row 882...
# ❌ No Methylobacterium match found in row 882.
# 🔍 BLASTing row 883...
# ✅ Match(es) found: sp|B1LWY6.1| [Methylobacterium radiotolerans JCM 2831] & sp|B0UR68.1| [Methylobacterium sp. 4-46] & sp|B8IIZ9.1| [Methylobacterium nodulans ORS 2060]
# 🔍 BLASTing row 884...
# ❌ No Methylobacterium match found in row 884.
# 🔍 BLASTing row 885...
# ❌ No Methylobacterium match found in row 885.
# 🔍 BLASTing row 886...
# ❌ No Methylobacterium match found in row 886.
# 🔍 BLASTing row 887...
# ❌ No Methylobacterium match found in row 887.
# 🔍 BLASTing row 888...
# ❌ No Methylobacterium match found in row 888.
# 🔍 BLASTing row 889...
# ❌ No Methylobacterium match found in row 889.
# 🔍 BLASTing row 890...
# ❌ No Methylobacterium match found in row 890.
# 🔍 BLASTing row 891...
# ❌ No Methylobacterium match found in row 891.
# 🔍 BLASTing row 892...
# ❌ No Methylobacterium match found in row 892.
# 🔍 BLASTing row 893...
# ❌ No Methylobacterium match found in row 893.
# 🔍 BLASTing row 894...
# ❌ No Methylobacterium match found in row 894.
# 🔍 BLASTing row 895...
# ❌ No Methylobacterium match found in row 895.
# 🔍 BLASTing row 896...
# ❌ No Methylobacterium match found in row 896.
# 🔍 BLASTing row 897...
# ❌ No Methylobacterium match found in row 897.
# 🔍 BLASTing row 898...
# ❌ No Methylobacterium match found in row 898.
# 🔍 BLASTing row 899...
# ❌ No Methylobacterium match found in row 899.
# 🔍 BLASTing row 900...
# ❌ No Methylobacterium match found in row 900.
# 🔍 BLASTing row 901...
# ❌ No Methylobacterium match found in row 901.
# 🔍 BLASTing row 902...
# ❌ No Methylobacterium match found in row 902.
# 🔍 BLASTing row 903...
# ❌ No Methylobacterium match found in row 903.
# 🔍 BLASTing row 904...
# ❌ No Methylobacterium match found in row 904.
# 🔍 BLASTing row 905...
# ❌ No Methylobacterium match found in row 905.
# 🔍 BLASTing row 906...
# ❌ No Methylobacterium match found in row 906.
# 🔍 BLASTing row 907...
# ❌ No Methylobacterium match found in row 907.
# 🔍 BLASTing row 908...
# ❌ No Methylobacterium match found in row 908.
# 🔍 BLASTing row 909...
# ❌ No Methylobacterium match found in row 909.
# 🔍 BLASTing row 910...
# ❌ No Methylobacterium match found in row 910.
# 🔍 BLASTing row 911...
# ❌ No Methylobacterium match found in row 911.
# 🔍 BLASTing row 912...
# ❌ No Methylobacterium match found in row 912.

# %%
# Add results to DataFrame and save
df['Local_BLAST_GPR'] = gpr_list
df.to_csv("SwissProt_BLAST_GPR_Complete.csv", index=False)
print("✅ Finished. Output saved to SwissProt_BLAST_GPR_COmplete.csv")
# Out:
# ✅ Finished. Output saved to SwissProt_BLAST_GPR_COmplete.csv
